# %% [markdown]
# AVISO: Este notebook fue ejecutado en Google Colab Pro en A100GPU

# %%
from docling.document_converter import DocumentConverter
converter = DocumentConverter()

# %%
from docling_core.transforms.chunker import HierarchicalChunker

sample_pdf = "./resources/manuals/Archer AX11000.pdf"
# most resource-intensive part
converted_result = converter.convert(sample_pdf) # interpreta el contenido y es parseado en un formato estructurado

doc = converted_result.document
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# otslp_all_standard_094_clean.check:   0%|          | 0.00/213M [00:00<?, ?B/s]
# otslp_all_fast.check:   0%|          | 0.00/146M [00:00<?, ?B/s]
# model.pt:   0%|          | 0.00/202M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# .gitignore:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.49k [00:00<?, ?B/s]
# (…)artifacts/tableformer/fat/tm_config.json:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# (…)del_artifacts/tableformer/tm_config.json:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
doc
# Out:
# DoclingDocument(schema_name='DoclingDocument', version='1.0.0', name='Archer AX11000', origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None), furniture=GroupItem(self_ref='#/furniture', parent=None, children=[], name='_root_', label=<GroupLabel.UNSPECIFIED: 'unspecified'>), body=GroupItem(self_ref='#/body', parent=None, children=[RefItem(cref='#/pictures/0'), RefItem(cref='#/texts/0'), RefItem(cref='#/texts/1'), RefItem(cref='#/texts/2'), RefItem(cref='#/texts/3'), RefItem(cref='#/tables/0'), RefItem(cref='#/tables/1'), RefItem(cref='#/tables/2'), RefItem(cref='#/texts/4'), RefItem(cref='#/texts/5'), RefItem(cref='#/texts/6'), RefItem(cref='#/texts/7'), RefItem(cref='#/tables/3'), RefItem(cref='#/texts/8'), RefItem(cref='#/texts/9'), RefItem(cref='#/texts/10'), RefItem(cref='#/texts/11'), RefItem(cref='#/texts/12'), RefItem(cref='#/texts/13'), RefItem(cref='#/texts/14'), RefItem(cref='#/texts/15'), RefItem(cref='#/texts/16'), RefItem(cref='#/texts/17'), RefItem(cref='#/texts/18'), RefItem(cref='#/texts/19'), RefItem(cref='#/texts/20'), RefItem(cref='#/texts/21'), RefItem(cref='#/texts/22'), RefItem(cref='#/groups/0'), RefItem(cref='#/texts/25'), RefItem(cref='#/texts/26'), RefItem(cref='#/texts/27'), RefItem(cref='#/texts/28'), RefItem(cref='#/texts/29'), RefItem(cref='#/texts/30'), RefItem(cref='#/texts/31'), RefItem(cref='#/texts/32'), RefItem(cref='#/pictures/1'), RefItem(cref='#/texts/33'), RefItem(cref='#/texts/34'), RefItem(cref='#/texts/35'), RefItem(cref='#/texts/36'), RefItem(cref='#/tables/4'), RefItem(cref='#/texts/37'), RefItem(cref='#/pictures/2'), RefItem(cref='#/texts/38'), RefItem(cref='#/texts/39'), RefItem(cref='#/texts/40'), RefItem(cref='#/texts/41'), RefItem(cref='#/tables/5'), RefItem(cref='#/pictures/3'), RefItem(cref='#/texts/42'), RefItem(cref='#/tables/6'), RefItem(cref='#/texts/43'), RefItem(cref='#/texts/44'), RefItem(cref='#/texts/45'), RefItem(cref='#/texts/46'), RefItem(cref='#/groups/1'), RefItem(cref='#/texts/49'), RefItem(cref='#/texts/50'), RefItem(cref='#/texts/51'), RefItem(cref='#/groups/2'), RefItem(cref='#/texts/57'), RefItem(cref='#/texts/58'), RefItem(cref='#/pictures/4'), RefItem(cref='#/texts/59'), RefItem(cref='#/pictures/5'), RefItem(cref='#/texts/60'), RefItem(cref='#/texts/61'), RefItem(cref='#/texts/62'), RefItem(cref='#/groups/3'), RefItem(cref='#/texts/69'), RefItem(cref='#/groups/4'), RefItem(cref='#/pictures/6'), RefItem(cref='#/pictures/7'), RefItem(cref='#/texts/73'), RefItem(cref='#/texts/74'), RefItem(cref='#/texts/75'), RefItem(cref='#/texts/76'), RefItem(cref='#/groups/5'), RefItem(cref='#/texts/81'), RefItem(cref='#/texts/82'), RefItem(cref='#/texts/83'), RefItem(cref='#/pictures/8'), RefItem(cref='#/pictures/9'), RefItem(cref='#/texts/84'), RefItem(cref='#/texts/85'), RefItem(cref='#/texts/86'), RefItem(cref='#/texts/87'), RefItem(cref='#/texts/88'), RefItem(cref='#/texts/89'), RefItem(cref='#/texts/90'), RefItem(cref='#/groups/6'), RefItem(cref='#/texts/92'), RefItem(cref='#/groups/7'), RefItem(cref='#/pictures/10'), RefItem(cref='#/texts/94'), RefItem(cref='#/groups/8'), RefItem(cref='#/texts/97'), RefItem(cref='#/texts/98'), RefItem(cref='#/texts/99'), RefItem(cref='#/texts/100'), RefItem(cref='#/texts/101'), RefItem(cref='#/groups/9'), RefItem(cref='#/texts/107'), RefItem(cref='#/texts/108'), RefItem(cref='#/texts/109'), RefItem(cref='#/texts/110'), RefItem(cref='#/groups/10'), RefItem(cref='#/texts/112'), RefItem(cref='#/groups/11'), RefItem(cref='#/pictures/11'), RefItem(cref='#/texts/116'), RefItem(cref='#/groups/12'), RefItem(cref='#/texts/120'), RefItem(cref='#/groups/13'), RefItem(cref='#/texts/122'), RefItem(cref='#/texts/123'), RefItem(cref='#/texts/124'), RefItem(cref='#/texts/125'), RefItem(cref='#/pictures/12'), RefItem(cref='#/texts/126'), RefItem(cref='#/pictures/13'), RefItem(cref='#/pictures/14'), RefItem(cref='#/groups/14'), RefItem(cref='#/pictures/15'), RefItem(cref='#/groups ...

# %% [markdown]
# La variable doc es la que se pasará como input a nuestro chunker avanzado. Sin embargo, podemos probar a hacer primeramente un chunking jerárquico de ese doc (hier_chunks no es usado en el resto del documento, el chunker avanzado hará de forma automático este mismo chunking para doc y después hará el refinado por límite de tokens)

# %%
hier_chunks = list(HierarchicalChunker().chunk(doc))

# %%
hier_chunks
# Out:
# [DocChunk(text='User Guide', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/0', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=189.30670166015625, t=485.01727294921875, r=415.20269775390625, b=397.41326904296875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 10))], orig='User Guide', text='User Guide')], headings=None, captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='AX11000 MU-MIMO Tri-Band Gaming Router Archer AX11000', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/1', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=162.2770233154297, t=420.9349670410156, r=448.6476135253906, b=375.0569763183594, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 53))], orig='AX11000 MU-MIMO Tri-Band Gaming Router Archer AX11000', text='AX11000 MU-MIMO Tri-Band Gaming Router Archer AX11000')], headings=None, captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='REV1.0.0 1910012505', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/2', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=1, bbox=BoundingBox(l=457.7597961425781, t=63.59379577636719, r=513.071533203125, b=53.638797760009766, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 19))], orig='REV1.0.0 1910012505', text='REV1.0.0 1910012505')], headings=None, captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='About This Guide .........................................................................................................1, 1 = About This Guide .........................................................................................................1. About This Guide .........................................................................................................1, 2 = . Chapter 1. Get to Know About Your Router . . . . . . . . . . . . . . . . . . . . . . . . . . . 3, 1 = Chapter 1. Get to Know About Your Router . . . . . . . . . . . . . . . . . . . . . . . . . . . 3. Chapter 1. Get to Know About Your Router . . . . . . . . . . . . . . . . . . . . . . . . . . . 3, 2 = . 1. 1., 1 = Product Overview. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. 1. 1., 2 = 4. 2., 1 = Panel Layout. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. 2., 2 = . , 1 = 1. 2. 1.Top View . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. , 2 = 4. , 1 = 2. 2.The Side and Back Panel. , 2 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 5. Chapter 2. Connect the Hardware . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 7, 1 = Chapter 2. Connect the Hardware . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 7. Chapter 2. Connect the Hardware . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 7, 2 = . 2. 1., 1 = Position Your Router . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. 2. 1., 2 = 8. 2., 1 = Connect Your Router. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .. 2., 2 = . Chapter 3. Log In to Your Router. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 11, 1 = Chapter 3. Log In to Your Router. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 11. Chapter 3. Log In to Your Router. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 11, 2 = . Chapter 4. Set Up Internet Connection . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13, 1 = Chapter 4. Set Up Internet Connection . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13. Chapter 4. Set Up Internet Connection . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 13, 2 = . 4. 1., 1 = Use Quick Setup Wizard. 4. 1., 2 = . , 1 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 14 Quick Setup via Bluetooth with TP-Link Tether App . . . . . . . . . . . . . . . . . . . . . . . . . . 14. , 2 = . 2.  4. 3., 1 = Manually Set Up Your Internet Connection. 2.  4. 3., 2 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 15. 4., 1 = Set Up the Router as an Access Point . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 18. 4., 2 = . 4. 5., 1 = Set Up an IPv6 Internet Connection . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 19. 4. 5., 2 = . Chapter 5. TP-Link Cloud Service . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 23, 1 = Chapter 5. TP-Link Cloud Service . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 23. Chapter 5. TP-Link Cloud Service . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 23, 2 = . 5. 1., 1 = Register a TP-Link ID. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 24. 5. 1., 2 = . 2., 1 = Change Your TP-Link ID Information. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 24. 2., 2 = . 5. 3., 1 = Manage the User TP-Link IDs. 5. 3., 2 = . . . . . . .  ...
#  DocChunk(text=", 1 = 7. 1. 1.Access the USB Device Locally . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 33. , 1 = 1. 2.Access the USB Device Remotely . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 34 7. 1. 3.Customize the Access Settings. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 36. 7. 2., 1 = Media Sharing . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 38. 3., 1 = Time Machine . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 39. Chapter 8. HomeCare - Parental Controls, QoS, Antivirus. . . . . . . . . . . 41, 1 = Chapter 8. HomeCare - Parental Controls, QoS, Antivirus. . . . . . . . . . . 41. 8. 1., 1 = Parental Controls . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 42. , 1 = 8. 1. 1.Scenario 1: Setting Up Access Restrictions . . . . . . . . . . . . . . . . . . . . . . . . . . . 42. , 1 = 1. 2.Scenario 2: Monitoring Internet Usage . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 44. 8. 2., 1 = QoS . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 46. 3., 1 = Antivirus . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 47. Chapter 9. Network Security . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 49, 1 = Chapter 9. Network Security . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 49. 9. 1., 1 = Protect the Network from Cyber Attacks . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 50. 2., 1 = Access Control . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 50. 9. 3., 1 = IP & MAC Binding . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 53. Chapter 10.NAT Forwarding. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 55, 1 = Chapter 10.NAT Forwarding. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 55. 10. 1., 1 = Share Local Resources on the Internet by Port Forwarding . . . . . . . . . . . . . . . . . . 56. 2., 1 = Open Ports Dynamically by Port Triggering . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 58. 10. 3., 1 = Make Applications Free from Port Restriction by DMZ . . . . . . . . . . . . . . . . . . . . . . . 59. 4., 1 = Make Xbox Online Games Run Smoothly by UPnP . . . . . . . . . . . . . . . . . . . . . . . . . . . 60. Chapter 11.VPN Server . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 62, 1 = Chapter 11.VPN Server . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 62. 11. 1., 1 = Use OpenVPN to Access Your Home Network . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 63. 2., 1 = Use PPTP VPN to Access Your Home Network . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 64. Chapter 12.Customize Your Network Settings. . . . . . . . . . . . . . . . . . . . . . . 70, 1 = Chapter 12.Customize Your Network Settings. . . . . . . . . . . . . . . . . . . . . . . 70. 12. 1., 1 = Change the LAN Settings . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 71. 2., 1 = Set Up Link Aggregation . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 71. 12. 3., 1 = Configure to Support IPTV Service. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 72. 4., 1 = Specify DHCP Server Settings . . . . . . . ...
#  DocChunk(text=", 1 = 12. 9. 2.Connect via the Router's PIN . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 81. , 1 = 9. 3.Push the WPS Button . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 82. 12. 10. Use WDS to Extend Network, 1 = 12. 10. Use WDS to Extend Network. 11. Advanced Wireless Settings . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 83 Chapter 13.Manage the Router, 1 = 11. Advanced Wireless Settings . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 83 Chapter 13.Manage the Router. , 1 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 85 Upgrade the Firmware. 13. 1., 1 = . , 1 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 86 13. 1. 1.Online Upgrade . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 86. , 1 = 1. 2.Local Upgrade . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 87. 13. 2., 1 = Backup and Restore Configuration Settings . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 87 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 89. 3., 1 = Change the Login Password. 13. 4., 1 = Password Recovery. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 89. 5., 1 = Local Management . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 90. 13. 6.  7., 1 = Remote Management . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 92 System Log. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 93. 13. 8., 1 = Test the Network Connectivity . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 95. 9., 1 = Set Up System Time . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 97. 13., 1 = 10. Set the Router to Reboot Regularly. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 99 11. Control the LED. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .100. 13., 1 = 12. Test Your Internet Speed . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .100. Chapter 14.Game Center, 1 = Chapter 14.Game Center. 14. 1., 1 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 102 Check Key Parameters through Dashboard. 2., 1 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .103 Boost Game Speed through Game Accelerator. . . . . . . . . . . . . . . . . . . . . . . . . . . . .104. 14. 3., 1 = TP-Link Router Skill for Alexa. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .105. 4., 1 = IFTTT. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .106. 14. 5., 1 = Game Protector. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .107. 6., 1 = VPN Server. 14. 7., 1 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .107 Port Forwarding. 8., 1 = . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .108 Game Diagnostics . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .108. FAQ .................. ...
#  DocChunk(text='About This Guide', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/4', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=85.03939819335938, t=726.8614501953125, r=340.2394104003906, b=663.1494750976562, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 16))], orig='About This Guide', text='About This Guide')], headings=['Contents'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='When using this guide, please notice that features of the router may vary slightly depending on the model and software version you have, and on your location, language, and internet service provider. All screenshots, images, parameters and descriptions documented in this guide are used for demonstration only.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/5', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.14472198486328, t=630.5579223632812, r=517.8552856445312, b=560.6419067382812, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 310))], orig='When using this guide, please notice that features of the router may vary slightly depending on the model and software version you have, and on your location, language, and internet service provider. All screenshots, images, parameters and descriptions documented in this guide are used for demonstration only.', text='When using this guide, please notice that features of the router may vary slightly depending on the model and software version you have, and on your location, language, and internet service provider. All screenshots, images, parameters and descriptions documented in this guide are used for demonstration only.')], headings=['Contents'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='This guide is a complement of Quick Installation Guide. The Quick Installation Guide instructs you on quick internet setup, and this guide provides details of each function and shows you the way to configure these functions appropriate to your needs.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/6', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.25878143310547, t=682.532958984375, r=516.77734375, b=628.6219482421875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 250))], orig='This guide is a complement of Quick Installation Guide. The Quick Installation Guide instructs you on quick internet setup, and this guide provides details of each function and shows you the way to configure these functions appropriate to your needs.', text='This guide is a complement of Quick Installation Guide. The Quick Installation Guide instructs you on quick internet setup, and this guide provides details of each function and shows you the way to configure these functions appropriate to your needs.')], headings=['Contents'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Underlined, Description = Underlined words or phrases are hyperlinks. You can click to redirect to a  website or a specific section.. Teal, Description = Contents to be emphasized and texts on the web page are in teal, including the  menus, items, buttons, etc.. >, Description = The menu structures to show the path to load the corresponding page. For  example,  Advanced  >  Wireless  >  WDS  means the WDS function page is under  the Wireless menu that is located in the Advanced tab.. Note:, Description = Ignoring this type of note might result in a malfunction or damage to the device.. Tips:, Description = Indicates important information that helps you make better use of your device.. symbols on the web  page, Description = ·   click to edit the corresponding entry. ·   click to delete the corresponding entry. ·   click to view more information about items on the page.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TableItem(self_ref='#/tables/3', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TABLE: 'table'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.80841827392578, t=517.75146484375, r=513.3442993164062, b=281.36004638671875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 0))], captions=[], references=[], footnotes=[], image=None, data=TableData(table_cells=[TableCell(bbox=BoundingBox(l=104.81780242919922, t=517.0668334960938, r=165.11981201171875, b=495.1658630371094, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='Convention', column_header=True, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=318.2727966308594, t=517.0668334960938, r=379.6858215332031, b=495.1658630371094, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='Description', column_header=True, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=112.60379791259766, t=491.069580078125, r=157.33380126953125, b=473.15057373046875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='Underlined', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=190.06680297851562, t=497.07257080078125, r=511.86004638671875, b=467.15655517578125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='Underlined words or phrases are hyperlinks. You can click to redirect to a  website or a specific section.', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=127.87680053710938, t=460.0195617675781, r=144.0677947998047, b=442.1005554199219, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='Teal', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=190.06680297851562, t=466.0225524902344, r=509.83502197265625, b=436.1065368652344, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='Contents to be emphasized and texts on the web page are in teal, including the  menus, items, buttons, etc.', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=132.3048095703125, t=422.9755554199219, r=137.6328125, b=405.0565490722656, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=0, ...
#  DocChunk(text='In this guide the following conventions are used:', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/8', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.69719696044922, t=538.0919189453125, r=323.4170837402344, b=516.19091796875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 49))], orig='In this guide the following conventions are used:', text='In this guide the following conventions are used:')], headings=['Conventions'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='*Maximum wireless signal rates are the physical rates derived from IEEE Standard 802.11 specifications. Actual wireless data throughput and wireless coverage are not guaranteed and will vary as a result of network conditions, client limitations, and environmental factors, including building materials, obstacles, volume and density of traffic, and client location.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/9', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.37889862060547, t=272.62896728515625, r=518.373291015625, b=186.70794677734375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 365))], orig='*Maximum wireless signal rates are the physical rates derived from IEEE Standard 802.11 specifications. Actual wireless data throughput and wireless coverage are not guaranteed and will vary as a result of network conditions, client limitations, and environmental factors, including building materials, obstacles, volume and density of traffic, and client location.', text='*Maximum wireless signal rates are the physical rates derived from IEEE Standard 802.11 specifications. Actual wireless data throughput and wireless coverage are not guaranteed and will vary as a result of network conditions, client limitations, and environmental factors, including building materials, obstacles, volume and density of traffic, and client location.')], headings=['Conventions'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='*Use of MU-MIMO and 1024-QAM requires clients to also support those functions.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/10', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.52790832519531, t=188.64395141601562, r=493.7079772949219, b=166.74295043945312, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 78))], orig='*Use of MU-MIMO and 1024-QAM requires clients to also support those functions.', text='*Use of MU-MIMO and 1024-QAM requires clients to also support those functions.')], headings=['Conventions'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='The Quick Installation Guide can be found where you find this guide or inside the package of the router.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/12', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.63432312011719, t=108.21809387207031, r=517.75732421875, b=70.31208801269531, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 104))], orig='The Quick Installation Guide can be found where you find this guide or inside the package of the router.', text='The Quick Installation Guide can be found where you find this guide or inside the package of the router.')], headings=['More Info'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='The latest software, management app and utility can be found at Download Center at https://www.tp-link.com/support .', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/13', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.41978454589844, t=144.18809509277344, r=516.1259765625, b=106.28208923339844, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 116))], orig='The latest software, management app and utility can be found at Download Center at https://www.tp-link.com/support .', text='The latest software, management app and utility can be found at Download Center at https://www.tp-link.com/support .')], headings=['More Info'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Specifications can be found on the product page at https://www.tp-link.com .', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/14', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=84.60404205322266, t=72.24808502197266, r=463.7759094238281, b=50.34709167480469, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 76))], orig='Specifications can be found on the product page at https://www.tp-link.com .', text='Specifications can be found on the product page at https://www.tp-link.com .')], headings=['More Info'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='1', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/15', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=5, bbox=BoundingBox(l=507.708984375, t=54.60109329223633, r=513.0708618164062, b=36.68209457397461, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 1))], orig='1', text='1')], headings=['More Info'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='TP-Link Community is provided for you to discuss our products and share knowledge at https://community.tp-link.com .', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/16', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=6, bbox=BoundingBox(l=84.13288879394531, t=720.4983520507812, r=513.10400390625, b=682.5923461914062, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 116))], orig='TP-Link Community is provided for you to discuss our products and share knowledge at https://community.tp-link.com .', text='TP-Link Community is provided for you to discuss our products and share knowledge at https://community.tp-link.com .')], headings=['More Info'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Our Technical Support contact information can be found at the Contact Technical Support page at https://www.tp-link.com/support .', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/17', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=6, bbox=BoundingBox(l=84.37811279296875, t=684.5283203125, r=517.7344360351562, b=646.622314453125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 129))], orig='Our Technical Support contact information can be found at the Contact Technical Support page at https://www.tp-link.com/support .', text='Our Technical Support contact information can be found at the Contact Technical Support page at https://www.tp-link.com/support .')], headings=['More Info'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='2', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/18', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=6, bbox=BoundingBox(l=507.0163879394531, t=54.60109329223633, r=513.0708618164062, b=36.68209457397461, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 1))], orig='2', text='2')], headings=['More Info'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='This chapter introduces what the router can do and shows its appearance.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/21', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=7, bbox=BoundingBox(l=84.79783630371094, t=395.028076171875, r=455.08709716796875, b=373.1270751953125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 72))], orig='This chapter introduces what the router can do and shows its appearance.', text='This chapter introduces what the router can do and shows its appearance.')], headings=['Get to Know About Your Router'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='It contains the following sections:', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/22', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=7, bbox=BoundingBox(l=84.51899719238281, t=375.0630798339844, r=251.1042022705078, b=353.1620788574219, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 35))], orig='It contains the following sections:', text='It contains the following sections:')], headings=['Get to Know About Your Router'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='· Product Overview\nPanel Layout', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[ListItem(self_ref='#/texts/23', parent=RefItem(cref='#/groups/0'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=7, bbox=BoundingBox(l=84.57098388671875, t=353.39306640625, r=183.26502990722656, b=331.4920654296875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 18))], orig='· Product Overview', text='· Product Overview', enumerated=False, marker='-'), ListItem(self_ref='#/texts/24', parent=RefItem(cref='#/groups/0'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=7, bbox=BoundingBox(l=84.61820983886719, t=334.5610656738281, r=158.21473693847656, b=312.6600646972656, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 12))], orig='Panel Layout', text='Panel Layout', enumerated=False, marker='-')], headings=['Get to Know About Your Router'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Chapter 1', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/25', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_HEADER: 'page_header'>, prov=[ProvenanceItem(page_no=8, bbox=BoundingBox(l=84.60564422607422, t=760.4340209960938, r=130.01992797851562, b=740.5240478515625, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 9))], orig='Chapter 1', text='Chapter 1')], headings=['Get to Know About Your Router'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Get to Know About Your Router', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/26', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_HEADER: 'page_header'>, prov=[ProvenanceItem(page_no=8, bbox=BoundingBox(l=371.9529113769531, t=760.4321899414062, r=513.0712280273438, b=740.522216796875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 29))], orig='Get to Know About Your Router', text='Get to Know About Your Router')], headings=['Get to Know About Your Router'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Moreover, it is simple and convenient to set up and use the TP-Link router due to its intuitive web interface and the powerful Tether app.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/28', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=8, bbox=BoundingBox(l=84.4543228149414, t=605.7335205078125, r=516.558349609375, b=567.8275146484375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 138))], orig='Moreover, it is simple and convenient to set up and use the TP-Link router due to its intuitive web interface and the powerful Tether app.', text='Moreover, it is simple and convenient to set up and use the TP-Link router due to its intuitive web interface and the powerful Tether app.')], headings=['1. 1. Product Overview'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='The TP-Link router is designed to fully meet the need of Small Office/Home Office (SOHO) networks and users demanding higher networking performance. The powerful antennas ensure continuous Wi-Fi signal to all your devices while boosting widespread coverage throughout your home, and the built-in Ethernet ports supply high-speed connection to your wired devices.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/29', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=8, bbox=BoundingBox(l=84.13076782226562, t=689.7185668945312, r=517.2613525390625, b=603.7975463867188, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 362))], orig='The TP-Link router is designed to fully meet the need of Small Office/Home Office (SOHO) networks and users demanding higher networking performance. The powerful antennas ensure continuous Wi-Fi signal to all your devices while boosting widespread coverage throughout your home, and the built-in Ethernet ports supply high-speed connection to your wired devices.', text='The TP-Link router is designed to fully meet the need of Small Office/Home Office (SOHO) networks and users demanding higher networking performance. The powerful antennas ensure continuous Wi-Fi signal to all your devices while boosting widespread coverage throughout your home, and the built-in Ethernet ports supply high-speed connection to your wired devices.')], headings=['1. 1. Product Overview'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text="The router's LED is located on the top. You can check the router's working status by following the LED Explanation table.", meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/32', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.CAPTION: 'caption'>, prov=[ProvenanceItem(page_no=8, bbox=BoundingBox(l=84.1911849975586, t=191.21768188476562, r=516.492431640625, b=153.31167602539062, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 121))], orig="The router's LED is located on the top. You can check the router's working status by following the LED Explanation table.", text="The router's LED is located on the top. You can check the router's working status by following the LED Explanation table.")], headings=['1. 2. 1. Top View'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='4', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/33', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=8, bbox=BoundingBox(l=506.3325500488281, t=54.90409469604492, r=513.0709228515625, b=34.99409866333008, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 1))], orig='4', text='4')], headings=['1. 2. 1. Top View'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Chapter 1', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/34', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_HEADER: 'page_header'>, prov=[ProvenanceItem(page_no=9, bbox=BoundingBox(l=84.71810150146484, t=760.4340209960938, r=130.01992797851562, b=740.5240478515625, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 9))], orig='Chapter 1', text='Chapter 1')], headings=['1. 2. 1. Top View'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Get to Know About Your Router', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/35', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_HEADER: 'page_header'>, prov=[ProvenanceItem(page_no=9, bbox=BoundingBox(l=372.1625671386719, t=760.4321899414062, r=513.0712280273438, b=740.522216796875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 29))], orig='Get to Know About Your Router', text='Get to Know About Your Router')], headings=['1. 2. 1. Top View'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text=', Status Pulsing = Solid white. , Indication = The router is working normally.. , Status Pulsing = Solid red. , Indication = No internet connection.. , Status Pulsing = Solid  orange. , Indication = The router is connected to the internet, but the Wi-Fi is off.. , Status Pulsing = Pulsing  white. , Indication = The firmware is being upgraded, WPS connection is being  established or the router is being reset. Do not disconnect or  power off your router.. , Status Pulsing = Off. , Indication = Power is off or the LED is turned off.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TableItem(self_ref='#/tables/4', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TABLE: 'table'>, prov=[ProvenanceItem(page_no=9, bbox=BoundingBox(l=84.75718688964844, t=689.7130737304688, r=512.6035766601562, b=506.8942565917969, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 0))], captions=[], references=[], footnotes=[], image=None, data=TableData(table_cells=[TableCell(bbox=BoundingBox(l=117.67790222167969, t=688.0545654296875, r=147.86190795898438, b=666.153564453125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='Name', column_header=True, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=192.4449005126953, t=688.0545654296875, r=226.5229034423828, b=650.1382446289062, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='Status Pulsing', column_header=True, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=349.6018981933594, t=688.0545654296875, r=401.93988037109375, b=666.153564453125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=2, end_col_offset_idx=3, text='Indication', column_header=True, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=187.23260498046875, t=637.0072021484375, r=233.7257080078125, b=619.0881958007812, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='Solid white', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=244.6256103515625, t=637.0072021484375, r=368.79681396484375, b=619.0881958007812, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=2, end_col_offset_idx=3, text='The router is working normally.', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=191.40859985351562, t=617.9542236328125, r=227.54359436035156, b=600.0352172851562, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='Solid red', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=244.6256103515625, t=617.9542236328125, r=340.78070068359375, b=600.0352172851562, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=2, end_col_offset_idx=3, text='No internet connection.', column_header=False, row_header=False, row_sectio ...
#  DocChunk(text='5', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/38', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=9, bbox=BoundingBox(l=506.8216552734375, t=54.90409469604492, r=513.0709228515625, b=34.99409866333008, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 1))], orig='5', text='5')], headings=['1. 2. 2. The Side and Back Panel'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Chapter 1', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/39', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_HEADER: 'page_header'>, prov=[ProvenanceItem(page_no=10, bbox=BoundingBox(l=84.69313049316406, t=760.4340209960938, r=130.01992797851562, b=740.5240478515625, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 9))], orig='Chapter 1', text='Chapter 1')], headings=['1. 2. 2. The Side and Back Panel'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Get to Know About Your Router', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/40', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_HEADER: 'page_header'>, prov=[ProvenanceItem(page_no=10, bbox=BoundingBox(l=372.0556945800781, t=760.4321899414062, r=513.0712280273438, b=740.522216796875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 29))], orig='Get to Know About Your Router', text='Get to Know About Your Router')], headings=['1. 2. 2. The Side and Back Panel'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
# ...
#  DocChunk(text='備考2. "·"系指該項限用物質之百分比含量未超出百分比含量基準值。', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/1506', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=129, bbox=BoundingBox(l=86.38294219970703, t=210.92898559570312, r=458.2830810546875, b=176.656982421875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 34))], orig='備考2. "·"系指該項限用物質之百分比含量未超出百分比含量基準值。', text='備考2. "·"系指該項限用物質之百分比含量未超出百分比含量基準值。')], headings=['限用物質含有情況標示聲明書'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='備考3. " - " 系指該項限用物質為排除項目。', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/1507', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=129, bbox=BoundingBox(l=86.3962631225586, t=190.9609832763672, r=322.31109619140625, b=156.68898010253906, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 25))], orig='備考3. " - " 系指該項限用物質為排除項目。', text='備考3. " - " 系指該項限用物質為排除項目。')], headings=['限用物質含有情況標示聲明書'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Продукт сертифіковано згідно с правилами системи УкрСЕПРО на відповідність вимогам нормативних документів та вимогам, що передбачені чинними законодавчими актами України.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/1508', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=129, bbox=BoundingBox(l=84.50316619873047, t=117.41399383544922, r=515.7481689453125, b=63.12599563598633, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 170))], orig='Продукт сертифіковано згідно с правилами системи УкрСЕПРО на відповідність вимогам нормативних документів та вимогам, що передбачені чинними законодавчими актами України.', text='Продукт сертифіковано згідно с правилами системи УкрСЕПРО на відповідність вимогам нормативних документів та вимогам, що передбачені чинними законодавчими актами України.')], headings=['限用物質含有情況標示聲明書'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='125', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/1509', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=129, bbox=BoundingBox(l=495.1830139160156, t=54.90409469604492, r=513.0709838867188, b=34.99409866333008, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 3))], orig='125', text='125')], headings=['限用物質含有情況標示聲明書'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text="Do not attempt to disassemble, repair, or modify the device.\n· Keep the device away from water, fire, humidity or hot environments.\n· Do not use damaged charger or USB cable to charge the device.\n· Do not use the device where wireless devices are not allowed.\nDo not use any other chargers than those recommended\nAdapter shall be installed near the equipment and shall be easily accessible.\n· Use only power supplies which are provided by manufacturer and in the original packing of this product. If you have any questions, please don't hesitate to contact us.\n· Place the device with its bottom surface downward.", meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[ListItem(self_ref='#/texts/1511', parent=RefItem(cref='#/groups/303'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.5616226196289, t=643.8289794921875, r=416.70587158203125, b=619.93701171875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 60))], orig='Do not attempt to disassemble, repair, or modify the device.', text='Do not attempt to disassemble, repair, or modify the device.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1512', parent=RefItem(cref='#/groups/303'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.68468475341797, t=662.6690063476562, r=462.9146423339844, b=638.7770385742188, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 70))], orig='· Keep the device away from water, fire, humidity or hot environments.', text='· Keep the device away from water, fire, humidity or hot environments.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1513', parent=RefItem(cref='#/groups/303'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.43958282470703, t=624.9889526367188, r=441.1573791503906, b=601.0969848632812, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 63))], orig='· Do not use damaged charger or USB cable to charge the device.', text='· Do not use damaged charger or USB cable to charge the device.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1514', parent=RefItem(cref='#/groups/303'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.72210693359375, t=587.3088989257812, r=430.63336181640625, b=563.4169311523438, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 63))], orig='· Do not use the device where wireless devices are not allowed.', text='· Do not use the device where wireless devices are not allowed.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1515', parent=RefItem(cref='#/groups/303'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.64459991455078, t=606.14892578125, r=401.6695556640625, b=582.2569580078125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 52))], orig='Do not use any other chargers than those recommended', text='Do not use any other chargers than those recommended', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1516', parent=RefItem(cref='#/groups/303'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.55522918701172, t=568.4688720703125, r=504.17901611328125, b=544.576904296875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 77))], orig='Adapter shall be installed near the equipment and shall be easily accessible.', text='Adapter shall be installed near the equipment and shall be easily accessible.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1517', parent=RefItem(cref='#/groups/303'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=130, bbox=Bounding ...
#  DocChunk(text='Please read and follow the above safety information when operating the device. We cannot guarantee that no accidents or damage will occur due to improper use of the device. Please use this product with care and operate at your own risk.', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/1519', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.24468231201172, t=478.8664855957031, r=516.5369262695312, b=422.9824523925781, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 236))], orig='Please read and follow the above safety information when operating the device. We cannot guarantee that no accidents or damage will occur due to improper use of the device. Please use this product with care and operate at your own risk.', text='Please read and follow the above safety information when operating the device. We cannot guarantee that no accidents or damage will occur due to improper use of the device. Please use this product with care and operate at your own risk.')], headings=['Safety Information'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None))),
#  DocChunk(text='Symbol, 1 = Explanation. , 1 = DC voltage. , 1 = Indoor use only. , 1 = RECYCLING This product bears the selective sorting symbol for Waste electrical and electronic  equipment (WEEE). This means that this product must be handled pursuant to European  directive 2012/19/EU in order to be recycled or dismantled to minimize its impact on  the environment. User has the choice to give his product to a competent recycling organization or to the', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TableItem(self_ref='#/tables/8', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TABLE: 'table'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.32899475097656, t=401.4775390625, r=514.9525756835938, b=238.08255004882812, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 0))], captions=[], references=[], footnotes=[], image=None, data=TableData(table_cells=[TableCell(bbox=BoundingBox(l=107.14789581298828, t=398.68865966796875, r=138.33290100097656, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='Symbol', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85890197753906, t=398.68865966796875, r=209.72088623046875, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='Explanation', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=381.5171813964844, r=207.07431030273438, b=363.5981750488281, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='DC voltage', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=352.6785583496094, r=224.74041748046875, b=334.7595520019531, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='Indoor use only', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=327.98358154296875, r=514.9525756835938, b=250.0795440673828, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=1, end_col_offset_idx=2, text='RECYCLING This product bears the selective sorting symbol for Waste electrical and electronic  equipment (WEEE). This means that this product must be handled pursuant to European  directive 2012/19/EU in order to be recycled or dismantled to minimize its impact on  the environment. User has the choice to give his product to a competent recycling organization or to the', column_header=False, row_header=False, row_section=False)], num_rows=4, num_cols=2, grid=[[TableCell(bbox=BoundingBox(l=107.14789581298828, t=398.68865966796875, r=138.33290100097656, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_o ...
#  DocChunk(text='126', meta=DocMeta(schema_name='docling_core.transforms.chunker.DocMeta', version='1.0.0', doc_items=[TextItem(self_ref='#/texts/1521', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=495.2316589355469, t=54.90409469604492, r=513.0709838867188, b=34.99409866333008, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 3))], orig='126', text='126')], headings=['Explanations of the symbols on the product label'], captions=None, origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)))]

# %%
from copy import deepcopy
from typing import Iterable, Iterator

from docling_core.transforms.chunker import (
    BaseChunk,
    BaseChunker,
    DocMeta,
    HierarchicalChunker,
)
from docling_core.types.doc import DoclingDocument as DLDocument
from pydantic import ConfigDict, PositiveInt
from transformers import AutoTokenizer
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
class MaxTokenLimitingChunker(BaseChunker):
    model_config = ConfigDict(arbitrary_types_allowed=True)

    inner_chunker: BaseChunker = HierarchicalChunker() # setamos el chunker jerárquico como primer chunking
    tokenizer: AutoTokenizer = AutoTokenizer.from_pretrained("BAAI/bge-small-en-v1.5")
    max_tokens: PositiveInt = 512
    delim: str = "\n"

    def _serialize_meta_to_include(self, meta: DocMeta) -> str:
        meta_parts = []
        headings_part = self.delim.join(meta.headings or []) # titulo de la seccion
        if headings_part:
            meta_parts.append(headings_part)
        captions_part = self.delim.join(meta.captions or []) # contenido (sera limitado por los max tokens)
        if captions_part:
            meta_parts.append(captions_part)
        return self.delim.join(meta_parts)

    def _split_above_max_tokens(self, chunk_iter: Iterable[BaseChunk]): # segundo tokenizador por limite de tokens
        for chunk in chunk_iter:
            meta = DocMeta.model_validate(chunk.meta)
            meta_text = self._serialize_meta_to_include(meta=meta) # coge los metadatos (titulos y captions)
            meta_list = [meta_text] if meta_text else []
            full_ser = self.delim.join(meta_list + ([chunk.text] if chunk.text else []))

            meta_tokens = self.tokenizer(
                meta_text, return_offsets_mapping=True, add_special_tokens=False
            )["offset_mapping"]
            delim_tokens = (
                self.tokenizer(
                    self.delim, return_offsets_mapping=True, add_special_tokens=False
                )["offset_mapping"]
                if meta_text
                else []
            )
            num_tokens_avail_for_text = self.max_tokens - (
                len(meta_tokens) + len(delim_tokens)
            )

            text_tokens = self.tokenizer(
                chunk.text, return_offsets_mapping=True, add_special_tokens=False
            )["offset_mapping"]
            num_text_tokens = len(text_tokens)

            if (
                num_text_tokens <= num_tokens_avail_for_text
            ):  # chunk already within token limit
                c = deepcopy(chunk)
                c.text = full_ser
                yield c
            else:  # chunk requires further splitting to meet token limit
                fitting_texts = [
                    chunk.text[
                        text_tokens[base][0] : text_tokens[
                            min(base + num_tokens_avail_for_text, num_text_tokens) - 1
                        ][1]
                    ]
                    for base in range(0, num_text_tokens, num_tokens_avail_for_text)
                ]
                for text in fitting_texts:
                    c = deepcopy(chunk)
                    c.text = self.delim.join(meta_list + [text])
                    yield c

    def chunk(self, dl_doc: DLDocument, **kwargs) -> Iterator[BaseChunk]:
        chunk_iter = self.inner_chunker.chunk(dl_doc=dl_doc, **kwargs) # procesa el documento y aplica el chunking jerarquico
        yield from self._split_above_max_tokens(chunk_iter=chunk_iter) # hace un segundo chunking con limite de tokens
# Out:
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
# inicializar MaxTokenLimitingChunker con los ajustes deseados
complete_chunker = MaxTokenLimitingChunker(
    inner_chunker=HierarchicalChunker(), # hierarchical chunker
    max_tokens=150  # token limit
)

final_chunks = list(complete_chunker.chunk(doc)) # primero se hace el chunking jerarquico y despues el del limitador de tokens

# final chunks ya contiene los chunks jerarquicos + con limite de tokens
for chunk in final_chunks:
    meta = DocMeta.model_validate(chunk.meta) # cogemos los metadatos
    # calcular el tamaño
    token_length = len(complete_chunker.tokenizer(chunk.text, return_offsets_mapping=True, add_special_tokens=False)["offset_mapping"])

    # Display de los datos
    print(f"Token Length: {token_length}")
    print("RAW Metadata:", meta)
    print("PARSED Metadata Fields:")
    for field, value in meta.__dict__.items():
        if field == "doc_items":
            print(f"  {field}:")
            for idx, item in enumerate(value):
                print(f"    Item {idx+1}:")
                for item_field, item_value in item.__dict__.items():
                    if item_field == "prov":
                        print(f"      {item_field}:")
                        for prov_idx, prov_item in enumerate(item_value):
                            print(f"        Provenance {prov_idx+1}:")
                            for prov_field, prov_value in prov_item.__dict__.items():
                                if prov_field == "bbox":
                                    print(f"          {prov_field}:")
                                    for bbox_field, bbox_value in prov_value.__dict__.items():
                                        print(f"            {bbox_field}: {bbox_value}")
                                else:
                                    print(f"          {prov_field}: {prov_value}")
                    else:
                        print(f"      {item_field}: {item_value}")
        else:
            print(f"  {field}: {value}")
    print("Chunk Text:", chunk.text)
    print("-" * 50)  # Separador para la lectura de entre los chunks
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2655 > 512). Running this sequence through the model will result in indexing errors
# Streaming output truncated to the last 5000 lines.
#       text: 4 ) Click SAVE .
#       enumerated: False
#       marker: -
#   headings: ['Note:']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Note:
# 1 ) Visit http://tplinkwifi.net , and log in with your TP-Link ID or the password you set for the router.
# 3 ) Modify the LAN IP address as the follow picture shows. Here we take 192.168.2.1 as an example.
# 2 ) Go to Advanced > Network > LAN .
# 4 ) Click SAVE .
# --------------------------------------------------
# Token Length: 150
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[ListItem(self_ref='#/texts/1338', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=84.46641540527344, t=483.1624755859375, r=264.2479553222656, b=461.261474609375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 35))], orig='· Restart the modem and the router.', text='· Restart the modem and the router.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1339', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.27738952636719, t=443.23248291015625, r=516.1502075195312, b=405.32647705078125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 101))], orig='2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.', text='2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1340', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.8319320678711, t=463.1974792480469, r=452.7549743652344, b=441.2964782714844, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 69))], orig='1 ) Power off your modem and router, and leave them off for 1 minute.', text='1 ) Power off your modem and router, and leave them off for 1 minute.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1341', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.47442626953125, t=407.2624816894531, r=224.52923583984375, b=385.3614807128906, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 24))], orig='3 ) Power on the router.', text='3 ) Power on the router.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1342', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=84.4429702758789, t=368.4654846191406, r=309.3468933105469, b=346.5644836425781, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 44))], orig='· Double check the internet connection type.', text='· Double check the internet connection type.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1343', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.53166961669922, t=387.2974853515625, r=417.16888427734375, b=365.396484375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 62))], orig='4 ) Wait another 1 or 2 minutes and check the internet access.', text='4 ) Wait another 1 or 2 minutes and check the internet access.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1344', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.88330841064453, t=348.50048828125, r=490.82598876953125, b=326.5994873046875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 77))], orig='1 ) Confirm your internet connection type, which can be learned from the ISP.', text='1 ) Confirm your internet connection type, which can be learned from the ISP.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1345', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.36524963378906, t=292.56549072265625, r=311.84832763671875, b=270.66448974609375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 41))], orig='3 ) Go to Advanced > N ...
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1338
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 84.46641540527344
#             t: 483.1624755859375
#             r: 264.2479553222656
#             b: 461.261474609375
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 35)
#       orig: · Restart the modem and the router.
#       text: · Restart the modem and the router.
#       enumerated: False
#       marker: -
#     Item 2:
#       self_ref: #/texts/1339
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.27738952636719
#             t: 443.23248291015625
#             r: 516.1502075195312
#             b: 405.32647705078125
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 101)
#       orig: 2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.
#       text: 2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.
#       enumerated: False
#       marker: -
#     Item 3:
#       self_ref: #/texts/1340
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.8319320678711
#             t: 463.1974792480469
#             r: 452.7549743652344
#             b: 441.2964782714844
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 69)
#       orig: 1 ) Power off your modem and router, and leave them off for 1 minute.
#       text: 1 ) Power off your modem and router, and leave them off for 1 minute.
#       enumerated: False
#       marker: -
#     Item 4:
#       self_ref: #/texts/1341
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.47442626953125
#             t: 407.2624816894531
#             r: 224.52923583984375
#             b: 385.3614807128906
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 24)
#       orig: 3 ) Power on the router.
#       text: 3 ) Power on the router.
#       enumerated: False
#       marker: -
#     Item 5:
#       self_ref: #/texts/1342
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 84.4429702758789
#             t: 368.4654846191406
#             r: 309.3468933105469
#             b: 346.5644836425781
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 44)
#       orig: · Double check the internet connection type.
#       text: · Double check the internet connection type.
#       enumerated: False
#       marker: -
#     Item 6:
#       self_ref: #/texts/1343
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.53166961669922
#             t: 387.2974853515625
#             r: 417.16888427734375
#             b: 365.396484375
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 62)
#       orig: 4 ) Wait another 1 or 2 minutes and check the internet access.
#       text: 4 ) Wait another 1 or 2 minutes and check the internet access.
#       enumerated: False
#       marker: -
#     Item 7:
#       self_ref: #/texts/1344
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.88330841064453
#             t: 348.50048828125
#             r: 490.82598876953125
#             b: 326.5994873046875
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 77)
#       orig: 1 ) Confirm your internet connection type, which can be learned from the ISP.
#       text: 1 ) Confirm your internet connection type, which can be learned from the ISP.
#       enumerated: False
#       marker: -
#     Item 8:
#       self_ref: #/texts/1345
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.36524963378906
#             t: 292.56549072265625
#             r: 311.84832763671875
#             b: 270.66448974609375
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 41)
#       orig: 3 ) Go to Advanced > Network > Internet .
#       text: 3 ) Go to Advanced > Network > Internet .
#       enumerated: False
#       marker: -
#     Item 9:
#       self_ref: #/texts/1346
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.53081512451172
#             t: 328.5354919433594
#             r: 515.1393432617188
#             b: 290.6294860839844
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 105)
#       orig: 2 ) Visit http://tplinkwifi.net , and log in with your TP-Link ID or the password you set for the router.
#       text: 2 ) Visit http://tplinkwifi.net , and log in with your TP-Link ID or the password you set for the router.
#       enumerated: False
#       marker: -
#     Item 10:
#       self_ref: #/texts/1347
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.14759063720703
#             t: 272.6004943847656
#             r: 448.91607666015625
#             b: 250.69949340820312
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 70)
#       orig: 4 ) Select your Internet Connection Type and fill in other parameters.
#       text: 4 ) Select your Internet Connection Type and fill in other parameters.
#       enumerated: False
#       marker: -
#     Item 11:
#       self_ref: #/texts/1348
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.48401641845703
#             t: 252.63548278808594
#             r: 181.66334533691406
#             b: 230.7344970703125
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 16)
#       orig: 5 ) Click SAVE .
#       text: 5 ) Click SAVE .
#       enumerated: False
#       marker: -
#   headings: ['Note:']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Note:
# · Restart the modem and the router.
# 2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.
# 1 ) Power off your modem and router, and leave them off for 1 minute.
# 3 ) Power on the router.
# · Double check the internet connection type.
# 4 ) Wait another 1 or 2 minutes and check the internet access.
# 1 ) Confirm your internet connection type, which can be learned from the ISP.
# 3 ) Go to Advanced > Network > Internet .
# 2 ) Visit http://tplinkwifi.net , and log in with your TP-Link ID or the password you set for the router.
# 4 ) Select
# --------------------------------------------------
# Token Length: 17
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[ListItem(self_ref='#/texts/1338', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=84.46641540527344, t=483.1624755859375, r=264.2479553222656, b=461.261474609375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 35))], orig='· Restart the modem and the router.', text='· Restart the modem and the router.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1339', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.27738952636719, t=443.23248291015625, r=516.1502075195312, b=405.32647705078125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 101))], orig='2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.', text='2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1340', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.8319320678711, t=463.1974792480469, r=452.7549743652344, b=441.2964782714844, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 69))], orig='1 ) Power off your modem and router, and leave them off for 1 minute.', text='1 ) Power off your modem and router, and leave them off for 1 minute.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1341', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.47442626953125, t=407.2624816894531, r=224.52923583984375, b=385.3614807128906, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 24))], orig='3 ) Power on the router.', text='3 ) Power on the router.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1342', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=84.4429702758789, t=368.4654846191406, r=309.3468933105469, b=346.5644836425781, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 44))], orig='· Double check the internet connection type.', text='· Double check the internet connection type.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1343', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.53166961669922, t=387.2974853515625, r=417.16888427734375, b=365.396484375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 62))], orig='4 ) Wait another 1 or 2 minutes and check the internet access.', text='4 ) Wait another 1 or 2 minutes and check the internet access.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1344', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.88330841064453, t=348.50048828125, r=490.82598876953125, b=326.5994873046875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 77))], orig='1 ) Confirm your internet connection type, which can be learned from the ISP.', text='1 ) Confirm your internet connection type, which can be learned from the ISP.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1345', parent=RefItem(cref='#/groups/279'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=104.36524963378906, t=292.56549072265625, r=311.84832763671875, b=270.66448974609375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 41))], orig='3 ) Go to Advanced > N ...
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1338
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 84.46641540527344
#             t: 483.1624755859375
#             r: 264.2479553222656
#             b: 461.261474609375
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 35)
#       orig: · Restart the modem and the router.
#       text: · Restart the modem and the router.
#       enumerated: False
#       marker: -
#     Item 2:
#       self_ref: #/texts/1339
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.27738952636719
#             t: 443.23248291015625
#             r: 516.1502075195312
#             b: 405.32647705078125
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 101)
#       orig: 2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.
#       text: 2 ) Power on your modem first, and wait about 2 minutes until it get a solid cable or Internet light.
#       enumerated: False
#       marker: -
#     Item 3:
#       self_ref: #/texts/1340
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.8319320678711
#             t: 463.1974792480469
#             r: 452.7549743652344
#             b: 441.2964782714844
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 69)
#       orig: 1 ) Power off your modem and router, and leave them off for 1 minute.
#       text: 1 ) Power off your modem and router, and leave them off for 1 minute.
#       enumerated: False
#       marker: -
#     Item 4:
#       self_ref: #/texts/1341
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.47442626953125
#             t: 407.2624816894531
#             r: 224.52923583984375
#             b: 385.3614807128906
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 24)
#       orig: 3 ) Power on the router.
#       text: 3 ) Power on the router.
#       enumerated: False
#       marker: -
#     Item 5:
#       self_ref: #/texts/1342
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 84.4429702758789
#             t: 368.4654846191406
#             r: 309.3468933105469
#             b: 346.5644836425781
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 44)
#       orig: · Double check the internet connection type.
#       text: · Double check the internet connection type.
#       enumerated: False
#       marker: -
#     Item 6:
#       self_ref: #/texts/1343
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.53166961669922
#             t: 387.2974853515625
#             r: 417.16888427734375
#             b: 365.396484375
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 62)
#       orig: 4 ) Wait another 1 or 2 minutes and check the internet access.
#       text: 4 ) Wait another 1 or 2 minutes and check the internet access.
#       enumerated: False
#       marker: -
#     Item 7:
#       self_ref: #/texts/1344
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.88330841064453
#             t: 348.50048828125
#             r: 490.82598876953125
#             b: 326.5994873046875
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 77)
#       orig: 1 ) Confirm your internet connection type, which can be learned from the ISP.
#       text: 1 ) Confirm your internet connection type, which can be learned from the ISP.
#       enumerated: False
#       marker: -
#     Item 8:
#       self_ref: #/texts/1345
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.36524963378906
#             t: 292.56549072265625
#             r: 311.84832763671875
#             b: 270.66448974609375
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 41)
#       orig: 3 ) Go to Advanced > Network > Internet .
#       text: 3 ) Go to Advanced > Network > Internet .
#       enumerated: False
#       marker: -
#     Item 9:
#       self_ref: #/texts/1346
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.53081512451172
#             t: 328.5354919433594
#             r: 515.1393432617188
#             b: 290.6294860839844
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 105)
#       orig: 2 ) Visit http://tplinkwifi.net , and log in with your TP-Link ID or the password you set for the router.
#       text: 2 ) Visit http://tplinkwifi.net , and log in with your TP-Link ID or the password you set for the router.
#       enumerated: False
#       marker: -
#     Item 10:
#       self_ref: #/texts/1347
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.14759063720703
#             t: 272.6004943847656
#             r: 448.91607666015625
#             b: 250.69949340820312
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 70)
#       orig: 4 ) Select your Internet Connection Type and fill in other parameters.
#       text: 4 ) Select your Internet Connection Type and fill in other parameters.
#       enumerated: False
#       marker: -
#     Item 11:
#       self_ref: #/texts/1348
#       parent: cref='#/groups/279'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 104.48401641845703
#             t: 252.63548278808594
#             r: 181.66334533691406
#             b: 230.7344970703125
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 16)
#       orig: 5 ) Click SAVE .
#       text: 5 ) Click SAVE .
#       enumerated: False
#       marker: -
#   headings: ['Note:']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Note:
# your Internet Connection Type and fill in other parameters.
# 5 ) Click SAVE .
# --------------------------------------------------
# Token Length: 3
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[TextItem(self_ref='#/texts/1349', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=118, bbox=BoundingBox(l=495.1153564453125, t=54.90409469604492, r=513.0709838867188, b=34.99409866333008, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 3))], orig='114', text='114')] headings=['Note:'] captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1349
#       parent: cref='#/body'
#       children: []
#       label: page_footer
#       prov:
#         Provenance 1:
#           page_no: 118
#           bbox:
#             l: 495.1153564453125
#             t: 54.90409469604492
#             r: 513.0709838867188
#             b: 34.99409866333008
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 3)
#       orig: 114
#       text: 114
#   headings: ['Note:']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Note:
# 114
# --------------------------------------------------
# Token Length: 14
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[ListItem(self_ref='#/texts/1350', parent=RefItem(cref='#/groups/280'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=104.4737319946289, t=507.93829345703125, r=325.8356018066406, b=486.03729248046875, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 43))], orig='6 ) Restart the modem and the router again.', text='6 ) Restart the modem and the router again.', enumerated=False, marker='-')] headings=['Note:'] captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1350
#       parent: cref='#/groups/280'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 104.4737319946289
#             t: 507.93829345703125
#             r: 325.8356018066406
#             b: 486.03729248046875
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 43)
#       orig: 6 ) Restart the modem and the router again.
#       text: 6 ) Restart the modem and the router again.
#       enumerated: False
#       marker: -
#   headings: ['Note:']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Note:
# 6 ) Restart the modem and the router again.
# --------------------------------------------------
# Token Length: 23
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[TextItem(self_ref='#/texts/1351', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=84.59393310546875, t=469.14129638671875, r=515.7529296875, b=431.23529052734375, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 110))], orig="If you've tried every method above but still cannot access the internet, please contact the technical support.", text="If you've tried every method above but still cannot access the internet, please contact the technical support.")] headings=['Note:'] captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1351
#       parent: cref='#/body'
#       children: []
#       label: text
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 84.59393310546875
#             t: 469.14129638671875
#             r: 515.7529296875
#             b: 431.23529052734375
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 110)
#       orig: If you've tried every method above but still cannot access the internet, please contact the technical support.
#       text: If you've tried every method above but still cannot access the internet, please contact the technical support.
#   headings: ['Note:']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Note:
# If you've tried every method above but still cannot access the internet, please contact the technical support.
# --------------------------------------------------
# Token Length: 13
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[ListItem(self_ref='#/texts/1352', parent=RefItem(cref='#/groups/281'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=84.532958984375, t=489.1062927246094, r=302.1415710449219, b=467.2052917480469, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 44))], orig='· Please upgrade the firmware of the router.', text='· Please upgrade the firmware of the router.', enumerated=False, marker='-')] headings=['Note:'] captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1352
#       parent: cref='#/groups/281'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 84.532958984375
#             t: 489.1062927246094
#             r: 302.1415710449219
#             b: 467.2052917480469
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 44)
#       orig: · Please upgrade the firmware of the router.
#       text: · Please upgrade the firmware of the router.
#       enumerated: False
#       marker: -
#   headings: ['Note:']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Note:
# · Please upgrade the firmware of the router.
# --------------------------------------------------
# Token Length: 61
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[ListItem(self_ref='#/texts/1354', parent=RefItem(cref='#/groups/282'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=84.38287353515625, t=370.99609375, r=515.4485473632812, b=317.0850830078125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 191))], orig="· Make sure the wireless function of your device is enabled if you're using a laptop with built-in wireless adapter. You can refer to the relevant document or contact the laptop manufacturer.", text="· Make sure the wireless function of your device is enabled if you're using a laptop with built-in wireless adapter. You can refer to the relevant document or contact the laptop manufacturer.", enumerated=False, marker='-')] headings=['Q6. What should I do if I cannot find my wireless network or I cannot connect the wireless network?'] captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1354
#       parent: cref='#/groups/282'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 84.38287353515625
#             t: 370.99609375
#             r: 515.4485473632812
#             b: 317.0850830078125
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 191)
#       orig: · Make sure the wireless function of your device is enabled if you're using a laptop with built-in wireless adapter. You can refer to the relevant document or contact the laptop manufacturer.
#       text: · Make sure the wireless function of your device is enabled if you're using a laptop with built-in wireless adapter. You can refer to the relevant document or contact the laptop manufacturer.
#       enumerated: False
#       marker: -
#   headings: ['Q6. What should I do if I cannot find my wireless network or I cannot connect the wireless network?']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Q6. What should I do if I cannot find my wireless network or I cannot connect the wireless network?
# · Make sure the wireless function of your device is enabled if you're using a laptop with built-in wireless adapter. You can refer to the relevant document or contact the laptop manufacturer.
# --------------------------------------------------
# Token Length: 37
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[TextItem(self_ref='#/texts/1355', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=84.4304428100586, t=389.8280944824219, r=434.2398986816406, b=367.9270935058594, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 72))], orig='If you fail to find any wireless network, please follow the steps below:', text='If you fail to find any wireless network, please follow the steps below:')] headings=['Q6. What should I do if I cannot find my wireless network or I cannot connect the wireless network?'] captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1355
#       parent: cref='#/body'
#       children: []
#       label: text
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 84.4304428100586
#             t: 389.8280944824219
#             r: 434.2398986816406
#             b: 367.9270935058594
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 72)
#       orig: If you fail to find any wireless network, please follow the steps below:
#       text: If you fail to find any wireless network, please follow the steps below:
#   headings: ['Q6. What should I do if I cannot find my wireless network or I cannot connect the wireless network?']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Q6. What should I do if I cannot find my wireless network or I cannot connect the wireless network?
# If you fail to find any wireless network, please follow the steps below:
# --------------------------------------------------
# Token Length: 150
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[ListItem(self_ref='#/texts/1356', parent=RefItem(cref='#/groups/283'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=84.62130737304688, t=320.1540832519531, r=518.294189453125, b=282.2480773925781, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 102))], orig='· Make sure the wireless adapter driver is installed successfully and the wireless adapter is enabled.', text='· Make sure the wireless adapter driver is installed successfully and the wireless adapter is enabled.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1357', parent=RefItem(cref='#/groups/283'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=104.8833999633789, t=265.3520812988281, r=515.8984375, b=227.44607543945312, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 133))], orig='1 ) If you see the message No connections are available , it is usually because the wireless function is disabled or blocked somehow.', text='1 ) If you see the message No connections are available , it is usually because the wireless function is disabled or blocked somehow.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1358', parent=RefItem(cref='#/groups/283'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=104.04053497314453, t=285.31707763671875, r=197.97531127929688, b=263.41607666015625, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 14))], orig='· On Windows 7', text='· On Windows 7', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1359', parent=RefItem(cref='#/groups/283'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=104.4722671508789, t=229.382080078125, r=488.2729797363281, b=207.4810791015625, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 78))], orig='2 ) Click Troubleshoot and windows might be able to fix the problem by itself.', text='2 ) Click Troubleshoot and windows might be able to fix the problem by itself.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1360', parent=RefItem(cref='#/groups/283'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=104.8834228515625, t=190.5850830078125, r=517.7101440429688, b=136.674072265625, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 224))], orig='1 ) If you see the message Windows cannot configure this wireless connection , this is usually because windows configuration utility is disabled or you are running another wireless configuration tool to connect the wireless.', text='1 ) If you see the message Windows cannot configure this wireless connection , this is usually because windows configuration utility is disabled or you are running another wireless configuration tool to connect the wireless.', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1361', parent=RefItem(cref='#/groups/283'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=104.36910247802734, t=210.55007934570312, r=205.835205078125, b=188.64907836914062, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 15))], orig='· On Windows XP', text='· On Windows XP', enumerated=False, marker='-'), ListItem(self_ref='#/texts/1362', parent=RefItem(cref='#/groups/283'), children=[], label=<DocItemLabel.LIST_ITEM: 'list_item'>, prov=[ProvenanceItem(page_no=119, bbox=BoundingBox(l=104.30465698242188, t=138.61007690429688, r=457.40594482421875, b=116.70909118652344, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 76))], orig='2 ) Exit the wireless configuration tool (the TP-Link Utility, for example).', text='2 ) Exit the wire ...
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1356
#       parent: cref='#/groups/283'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 84.62130737304688
#             t: 320.1540832519531
#             r: 518.294189453125
#             b: 282.2480773925781
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 102)
#       orig: · Make sure the wireless adapter driver is installed successfully and the wireless adapter is enabled.
#       text: · Make sure the wireless adapter driver is installed successfully and the wireless adapter is enabled.
#       enumerated: False
#       marker: -
#     Item 2:
#       self_ref: #/texts/1357
#       parent: cref='#/groups/283'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 104.8833999633789
#             t: 265.3520812988281
#             r: 515.8984375
#             b: 227.44607543945312
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 133)
#       orig: 1 ) If you see the message No connections are available , it is usually because the wireless function is disabled or blocked somehow.
#       text: 1 ) If you see the message No connections are available , it is usually because the wireless function is disabled or blocked somehow.
#       enumerated: False
#       marker: -
#     Item 3:
#       self_ref: #/texts/1358
#       parent: cref='#/groups/283'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 104.04053497314453
#             t: 285.31707763671875
#             r: 197.97531127929688
#             b: 263.41607666015625
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 14)
#       orig: · On Windows 7
#       text: · On Windows 7
#       enumerated: False
#       marker: -
#     Item 4:
#       self_ref: #/texts/1359
#       parent: cref='#/groups/283'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 104.4722671508789
#             t: 229.382080078125
#             r: 488.2729797363281
#             b: 207.4810791015625
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 78)
#       orig: 2 ) Click Troubleshoot and windows might be able to fix the problem by itself.
#       text: 2 ) Click Troubleshoot and windows might be able to fix the problem by itself.
#       enumerated: False
#       marker: -
#     Item 5:
#       self_ref: #/texts/1360
#       parent: cref='#/groups/283'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 104.8834228515625
#             t: 190.5850830078125
#             r: 517.7101440429688
#             b: 136.674072265625
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 224)
#       orig: 1 ) If you see the message Windows cannot configure this wireless connection , this is usually because windows configuration utility is disabled or you are running another wireless configuration tool to connect the wireless.
#       text: 1 ) If you see the message Windows cannot configure this wireless connection , this is usually because windows configuration utility is disabled or you are running another wireless configuration tool to connect the wireless.
#       enumerated: False
#       marker: -
#     Item 6:
#       self_ref: #/texts/1361
#       parent: cref='#/groups/283'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 104.36910247802734
#             t: 210.55007934570312
#             r: 205.835205078125
#             b: 188.64907836914062
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 15)
#       orig: · On Windows XP
#       text: · On Windows XP
#       enumerated: False
#       marker: -
#     Item 7:
#       self_ref: #/texts/1362
#       parent: cref='#/groups/283'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 104.30465698242188
#             t: 138.61007690429688
#             r: 457.40594482421875
#             b: 116.70909118652344
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 76)
#       orig: 2 ) Exit the wireless configuration tool (the TP-Link Utility, for example).
#       text: 2 ) Exit the wireless configuration tool (the TP-Link Utility, for example).
#       enumerated: False
#       marker: -
#     Item 8:
#       self_ref: #/texts/1363
#       parent: cref='#/groups/283'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 119
#           bbox:
#             l: 104.30651092529297
#             t: 118.64508819580078
#             r: 517.2402954101562
#             b: 80.73908996582031
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 103)
#       orig: 3 ) Select and right click on My Computer on desktop, select Manage to open Computer Management window.
#       text: 3 ) Select and right click on My Computer on desktop, select Manage to open Computer Management window.
#       enumerated: False
#       marker: -
#   headings: ['Q6. What should I do if I cannot find my wireless network or I cannot connect the wireless network?']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Q6. What should I do if I cannot find my wireless network or I cannot connect the wireless network?
# · Make sure the wireless adapter driver is installed successfully and the wireless adapter is enabled.
# 1 ) If you see the message No connections are available , it is usually because the wireless function is disabled or blocked somehow.
# · On Windows 7
# 2 ) Click Troubleshoot and windows might be able to fix the problem by itself.
# 1 ) If you see the message Windows cannot configure this wireless connection , this is usually because windows configuration utility is disabled or you are running another wireless configuration tool to connect the wireless.
# · On Windows XP
# 2 ) Exit the wireless configuration tool (the TP-Link Utility, for example).
# 3
# --------------------------------------------------
# Token Length: 41
# ...
#           page_no: 130
#           bbox:
#             l: 84.55522918701172
#             t: 568.4688720703125
#             r: 504.17901611328125
#             b: 544.576904296875
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 77)
#       orig: Adapter shall be installed near the equipment and shall be easily accessible.
#       text: Adapter shall be installed near the equipment and shall be easily accessible.
#       enumerated: False
#       marker: -
#     Item 7:
#       self_ref: #/texts/1517
#       parent: cref='#/groups/303'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 130
#           bbox:
#             l: 84.2466049194336
#             t: 530.826416015625
#             r: 516.7998046875
#             b: 474.9424743652344
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 169)
#       orig: · Use only power supplies which are provided by manufacturer and in the original packing of this product. If you have any questions, please don't hesitate to contact us.
#       text: · Use only power supplies which are provided by manufacturer and in the original packing of this product. If you have any questions, please don't hesitate to contact us.
#       enumerated: False
#       marker: -
#     Item 8:
#       self_ref: #/texts/1518
#       parent: cref='#/groups/303'
#       children: []
#       label: list_item
#       prov:
#         Provenance 1:
#           page_no: 130
#           bbox:
#             l: 84.59156799316406
#             t: 549.6288452148438
#             r: 372.44659423828125
#             b: 525.7368774414062
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 52)
#       orig: · Place the device with its bottom surface downward.
#       text: · Place the device with its bottom surface downward.
#       enumerated: False
#       marker: -
#   headings: ['Safety Information']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Safety Information
# Do not attempt to disassemble, repair, or modify the device.
# · Keep the device away from water, fire, humidity or hot environments.
# · Do not use damaged charger or USB cable to charge the device.
# · Do not use the device where wireless devices are not allowed.
# Do not use any other chargers than those recommended
# Adapter shall be installed near the equipment and shall be easily accessible.
# · Use only power supplies which are provided by manufacturer and in the original packing of this product. If you have any questions, please don't hesitate to contact us.
# · Place the device with its bottom surface downward.
# --------------------------------------------------
# Token Length: 46
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[TextItem(self_ref='#/texts/1519', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TEXT: 'text'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.24468231201172, t=478.8664855957031, r=516.5369262695312, b=422.9824523925781, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 236))], orig='Please read and follow the above safety information when operating the device. We cannot guarantee that no accidents or damage will occur due to improper use of the device. Please use this product with care and operate at your own risk.', text='Please read and follow the above safety information when operating the device. We cannot guarantee that no accidents or damage will occur due to improper use of the device. Please use this product with care and operate at your own risk.')] headings=['Safety Information'] captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1519
#       parent: cref='#/body'
#       children: []
#       label: text
#       prov:
#         Provenance 1:
#           page_no: 130
#           bbox:
#             l: 84.24468231201172
#             t: 478.8664855957031
#             r: 516.5369262695312
#             b: 422.9824523925781
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 236)
#       orig: Please read and follow the above safety information when operating the device. We cannot guarantee that no accidents or damage will occur due to improper use of the device. Please use this product with care and operate at your own risk.
#       text: Please read and follow the above safety information when operating the device. We cannot guarantee that no accidents or damage will occur due to improper use of the device. Please use this product with care and operate at your own risk.
#   headings: ['Safety Information']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Safety Information
# Please read and follow the above safety information when operating the device. We cannot guarantee that no accidents or damage will occur due to improper use of the device. Please use this product with care and operate at your own risk.
# --------------------------------------------------
# Token Length: 91
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[TableItem(self_ref='#/tables/8', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.TABLE: 'table'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=84.32899475097656, t=401.4775390625, r=514.9525756835938, b=238.08255004882812, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 0))], captions=[], references=[], footnotes=[], image=None, data=TableData(table_cells=[TableCell(bbox=BoundingBox(l=107.14789581298828, t=398.68865966796875, r=138.33290100097656, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='Symbol', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85890197753906, t=398.68865966796875, r=209.72088623046875, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='Explanation', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=381.5171813964844, r=207.07431030273438, b=363.5981750488281, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='DC voltage', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=352.6785583496094, r=224.74041748046875, b=334.7595520019531, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='Indoor use only', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=327.98358154296875, r=514.9525756835938, b=250.0795440673828, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=1, end_col_offset_idx=2, text='RECYCLING This product bears the selective sorting symbol for Waste electrical and electronic  equipment (WEEE). This means that this product must be handled pursuant to European  directive 2012/19/EU in order to be recycled or dismantled to minimize its impact on  the environment. User has the choice to give his product to a competent recycling organization or to the', column_header=False, row_header=False, row_section=False)], num_rows=4, num_cols=2, grid=[[TableCell(bbox=BoundingBox(l=107.14789581298828, t=398.68865966796875, r=138.33290100097656, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='Symbol', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85890197753906, t=398.68865966796875, r=209.72088623046875, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='Explanation', column_header=False, row_ ...
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/tables/8
#       parent: cref='#/body'
#       children: []
#       label: table
#       prov:
#         Provenance 1:
#           page_no: 130
#           bbox:
#             l: 84.32899475097656
#             t: 401.4775390625
#             r: 514.9525756835938
#             b: 238.08255004882812
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 0)
#       captions: []
#       references: []
#       footnotes: []
#       image: None
#       data: table_cells=[TableCell(bbox=BoundingBox(l=107.14789581298828, t=398.68865966796875, r=138.33290100097656, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='Symbol', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85890197753906, t=398.68865966796875, r=209.72088623046875, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='Explanation', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=381.5171813964844, r=207.07431030273438, b=363.5981750488281, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=1, end_col_offset_idx=2, text='DC voltage', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=352.6785583496094, r=224.74041748046875, b=334.7595520019531, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=2, end_row_offset_idx=3, start_col_offset_idx=1, end_col_offset_idx=2, text='Indoor use only', column_header=False, row_header=False, row_section=False), TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=327.98358154296875, r=514.9525756835938, b=250.0795440673828, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=3, end_row_offset_idx=4, start_col_offset_idx=1, end_col_offset_idx=2, text='RECYCLING This product bears the selective sorting symbol for Waste electrical and electronic  equipment (WEEE). This means that this product must be handled pursuant to European  directive 2012/19/EU in order to be recycled or dismantled to minimize its impact on  the environment. User has the choice to give his product to a competent recycling organization or to the', column_header=False, row_header=False, row_section=False)] num_rows=4 num_cols=2 grid=[[TableCell(bbox=BoundingBox(l=107.14789581298828, t=398.68865966796875, r=138.33290100097656, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=0, end_col_offset_idx=1, text='Symbol', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85890197753906, t=398.68865966796875, r=209.72088623046875, b=380.7696533203125, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=0, end_row_offset_idx=1, start_col_offset_idx=1, end_col_offset_idx=2, text='Explanation', column_header=False, row_header=False, row_section=False)], [TableCell(bbox=None, row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx=2, start_col_offset_idx=0, end_col_offset_idx=1, text='', column_header=False, row_header=False, row_section=False), TableCell(bbox=BoundingBox(l=161.85830688476562, t=381.5171813964844, r=207.07431030273438, b=363.5981750488281, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), row_span=1, col_span=1, start_row_offset_idx=1, end_row_offset_idx= ...
#   headings: ['Safety Information']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Safety Information
# Symbol, 1 = Explanation. , 1 = DC voltage. , 1 = Indoor use only. , 1 = RECYCLING This product bears the selective sorting symbol for Waste electrical and electronic  equipment (WEEE). This means that this product must be handled pursuant to European  directive 2012/19/EU in order to be recycled or dismantled to minimize its impact on  the environment. User has the choice to give his product to a competent recycling organization or to the
# --------------------------------------------------
# Token Length: 9
# RAW Metadata: schema_name='docling_core.transforms.chunker.DocMeta' version='1.0.0' doc_items=[TextItem(self_ref='#/texts/1521', parent=RefItem(cref='#/body'), children=[], label=<DocItemLabel.PAGE_FOOTER: 'page_footer'>, prov=[ProvenanceItem(page_no=130, bbox=BoundingBox(l=495.2316589355469, t=54.90409469604492, r=513.0709838867188, b=34.99409866333008, coord_origin=<CoordOrigin.BOTTOMLEFT: 'BOTTOMLEFT'>), charspan=(0, 3))], orig='126', text='126')] headings=['Explanations of the symbols on the product label'] captions=None origin=DocumentOrigin(mimetype='application/pdf', binary_hash=13203266288581993525, filename='Archer AX11000.pdf', uri=None)
# PARSED Metadata Fields:
#   schema_name: docling_core.transforms.chunker.DocMeta
#   version: 1.0.0
#   doc_items:
#     Item 1:
#       self_ref: #/texts/1521
#       parent: cref='#/body'
#       children: []
#       label: page_footer
#       prov:
#         Provenance 1:
#           page_no: 130
#           bbox:
#             l: 495.2316589355469
#             t: 54.90409469604492
#             r: 513.0709838867188
#             b: 34.99409866333008
#             coord_origin: BOTTOMLEFT
#           charspan: (0, 3)
#       orig: 126
#       text: 126
#   headings: ['Explanations of the symbols on the product label']
#   captions: None
#   origin: mimetype='application/pdf' binary_hash=13203266288581993525 filename='Archer AX11000.pdf' uri=None
# Chunk Text: Explanations of the symbols on the product label
# 126
# --------------------------------------------------
